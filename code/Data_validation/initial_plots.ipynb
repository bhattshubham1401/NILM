# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= (10,2)

# %%
lst = ['washing_machine',"ac1",'ac2',"fridge",'tv']
path = "d:/NILM/Data_files/Parquet/Appliances12_06-21_06/"
l = []
for i in range(len(lst)):
    df = pd.read_parquet(f"{path}{lst[i]}.parquet")
    print(lst[i],":",len(df))
    df.set_index(['timestamp'],inplace=True ,drop=True)
    l.append(df)
# Out:
# washing_machine : 2847
# ac1 : 46207
# ac2 : 20213
# fridge : 646625
# tv : 127913

# %%
x=0
for y in l:
    df= y
    for i in df.columns:
        df[i].plot()
        plt.title((lst[x],i))
        plt.xticks(rotation=15)
        plt.show()
    x+=1

# %%
x=0
for y in l:
    df= y
    # for i in df.columns:
    df['active'].plot()
    plt.title((lst[x],i))
    plt.xticks(rotation=15)
    plt.show()
    x+=1

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 9]

# Create a plot
plt.plot(x, y)

# Rotate x-axis labels with a 45-degree angle
plt.xticks(rotation=45)

# Show the plot
plt.show()
