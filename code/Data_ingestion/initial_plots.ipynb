# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= (10,2)

# %%
lst = ['washing_machine',"ac1",'ac2',"fridge",'tv']
path = "d:/NILM/Data_files/Parquet/Appliances12_06-04_08/"
l = []
for i in range(len(lst)):
    df = pd.read_parquet(f"{path}{lst[i]}.parquet")
    print(f"no of records in {lst[i]}:",len(df))
    df.set_index(['timestamp'],inplace=True ,drop=True)
    print(f"null in {lst[i]}:",df.isna().sum().sum())
    print(f"duplicates in {lst[i]}:",df.duplicated().sum())
    df.drop_duplicates(inplace=True)  
    l.append(df)
# Out:
# no of records in washing_machine: 20885
# null in washing_machine: 0
# duplicates in washing_machine: 323
# no of records in ac1: 337741
# null in ac1: 0
# duplicates in ac1: 2090
# no of records in ac2: 426581
# null in ac2: 0
# duplicates in ac2: 1889
# no of records in fridge: 4044212
# null in fridge: 0
# duplicates in fridge: 23890
# no of records in tv: 414714
# null in tv: 0
# duplicates in tv: 1232

# %%
x=0
for y in l:
    df= y
    for i in df.columns:
        df[i].plot()
        plt.title((lst[x],i))
        plt.xticks(rotation=15)
        plt.show()
    x+=1

# %%
x=0
for y in l:
    df= y
    # for i in df.columns:
    df['active'].plot()
    plt.title((lst[x],i))
    plt.xticks(rotation=15)
    plt.show()
    x+=1
